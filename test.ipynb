# %%
import pandas as pd


# reading the database
data = pd.read_csv("sample_test.csv")

# printing the top 10 rows
display(data.head(10))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
import matplotlib.pyplot as plt
 
 
# Scatter plot with day against tip
plt.scatter(data['day'], data['tip'], c=data['size'], 
            s=data['total_bill'])
 
# Adding Title to the Plot
plt.title("Scatter Plot")
 
# Setting the X and Y labels
plt.xlabel('Day')
plt.ylabel('Tip')
 
plt.colorbar()
 
plt.show()

# %%
# importing packages
import seaborn as sns

sns.scatterplot(x='day', y='tip', data=data,
			hue='sex')
plt.show()

# %%
# add percentage
data["new_column"]=100
data["percentage"]=round((data["tip"]/data["total_bill"])*100)
print(data.head())

sns.barplot(x='day',y='tip', data=data, 
 			hue='sex')

plt.show()
# Out:
#    total_bill   tip     sex smoker  day    time  size  new_column  percentage
# 0       16.99  1.01  Female     No  Sun  Dinner     2         100         6.0
# 1       10.34  1.66    Male     No  Sun  Dinner     3         100        16.0
# 2       21.01  3.50    Male     No  Sun  Dinner     3         100        17.0
# 3       23.68  3.31    Male     No  Sun  Dinner     2         100        14.0
# 4       24.59  3.61  Female     No  Sun  Dinner     4         100        15.0

# %%
sns.histplot(x='total_bill', data=data, kde=True, hue='sex')

plt.show()
# Out:
# /Users/smirzavand/opt/anaconda3/envs/localEnv/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import plotly.express as px
 
# plotting the scatter chart
fig = px.scatter(data, x="total_bill", y="tip", color="sex",
                 size='size')
 
# showing the plot
fig.show('svg')
